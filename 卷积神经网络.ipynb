# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 为何要用卷积模型

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 卷积神经网络的核心是自动求解过滤器的权重值

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 测试一下git功能
#
# 再盖一下
